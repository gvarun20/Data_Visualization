# %%
# !pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# LINE CHART

# %%
yield_apples=[.895,.91,.919,.926,.926,.931]

# %%
plt.plot(yield_apples);

# %%
years=[2010,2011,2013,2014,2015]
#or
#years=[y for y in range(2010,2015)]
yield_apples=[.895,.91,.919,.926,.926]

# %%
plt.plot(years,yield_apples)

# %%
plt.plot(years,yield_apples)
plt.xlabel('Year')
plt.ylabel('yield(tonper hectare)')
# Out:
# Text(0, 0.5, 'yield(tonper hectare)')

# %%
years = range(1999,2012)
apples =[0.895,.91,.919,.926,.926,.931,.934]
oranges =[.962,.941,.930,.934,.919,.911,.990]

# %%
years = [2000,2001,2002,2003,2004,2005,2006]
apples=[0.895,.91,.919,.926,.926,.931,.934]
oranges=[.962,.941,.930,.934,.919,.911,.990]

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel('year')
plt.ylabel('yield(ton per hectare)')
# Out:
# Text(0, 0.5, 'yield(ton per hectare)')

# %%
plt.plot(years,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='green')
plt.plot(years,oranges,marker='o',c='b',ls='-',lw=3, ms=2,mew=2,mec='red')
plt.xlabel('year')
plt.ylabel('yield(ton per hectare)')
plt.savefig("plotgraph.pdf", format="pdf")
plt.show()

# %%
plt.plot(years,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='green')
plt.plot(years,oranges,marker='o',c='b',ls='-',lw=3, ms=2,mew=2,mec='red')
plt.xlabel('year')
plt.ylabel('yield(ton per hectare)')
filename = "plotgraph.pdf"  
save_image(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 6>()
#       4 plt.ylabel('yield(ton per hectare)')
#       5 filename = "plotgraph.pdf"
# ----> 6 save_image(filename)
#
# NameError: name 'save_image' is not defined

# %%
#def save_image(filename):
    
    # PdfPages is a wrapper around pdf 
    # file so there is no clash and create
    # files with no error.
    p = PdfPages(filename)
      
    # get_fignums Return list of existing 
    # figure numbers
    fig_nums = plt.get_fignums()  
    figs = [plt.figure(n) for n in fig_nums]
      
    # iterating over the numbers in list
    for fig in figs: 
        
        # and saving the files
        fig.savefig(p, format='pdf') 
      
    # close the object
    p.close()  
  
# name your Pdf file
filename = "plotgraph.pdf" 
  
# call the function
save_image(filename)
# Out:
#   Input In [51]
#     p = PdfPages(filename)
#     ^
# IndentationError: unexpected indent

# %%
sns.set_style('darkgrid')
plt.plot(years,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='green')
plt.plot(years,oranges,marker='o',c='b',ls='-',lw=3, ms=2,mew=2,mec='red')
plt.xlabel('year')
plt.ylabel('yield(ton per hectare)')
# Out:
# Text(0, 0.5, 'yield(ton per hectare)')

# %%
sns.set_style('whitegrid')
plt.plot(years,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='green')
plt.plot(years,oranges,marker='o',c='b',ls='-',lw=3, ms=2,mew=2,mec='red')
plt.xlabel('year')
plt.ylabel('yield(ton per hectare)')
# Out:
# Text(0, 0.5, 'yield(ton per hectare)')

# %%
sns.set_style('ticks')
plt.plot(years,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='green')
plt.plot(years,oranges,marker='o',c='b',ls='-',lw=3, ms=2,mew=2,mec='red')
plt.xlabel('year')
plt.ylabel('yield(ton per hectare)')
# Out:
# Text(0, 0.5, 'yield(ton per hectare)')

# %%
sns.set_style('dark')
plt.plot(years,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='green')
plt.plot(years,oranges,marker='o',c='b',ls='-',lw=3, ms=2,mew=2,mec='red')
plt.xlabel('year')
plt.ylabel('yield(ton per hectare)')
# Out:
# Text(0, 0.5, 'yield(ton per hectare)')

# %%
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(9,10)
matplotlib.rcParams['figure.facecolor']='#00000000'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 matplotlib.rcParams['font.size']=14
#       2 matplotlib.rcParams['figure.figsize']=(9,10)
#       3 matplotlib.rcParams['figure.facecolor']='#00000000'
#
# NameError: name 'matplotlib' is not defined

# %%
flower_df =sns.load_dataset("iris")
flower_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flower_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flower_df.sepal_length,flower_df.sepal_width)

# %%
sns.scatterplot(x=flower_df.sepal_length,y=flower_df.sepal_width);
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
plt.title('Sepal Dimentions')
sns.scatterplot(x=flower_df.sepal_length,y=flower_df.sepal_width,hue=flower_df.species,s=100);

# %%
plt.title("DISTRIBUTION OF SEPAL WIDTH")
plt.hist(flower_df.sepal_width);

# %%
plt.hist(flower_df.sepal_width,bins=4);

# %%
import numpy as np
plt.hist(flower_df.sepal_width,bins=np.arange(2,6,.35));

# %%
plt.hist(flower_df.sepal_width,bins=[2,3,4,4.5]);
